# %% [markdown]
# Q.01 Who developed python programming language?
#  Ans:- Guido van Rossum
#
#
#  Q.02 Which type of programming does python support?
#  Ans:- object-oriented, structured, and functional programming.
#
#  Q.03 Is python is case sensitive when dealing with identifierd
#
# Ans:- Yes, Python is case-sensitive when dealing with identifiers.
#
# Q.04 What is the correct extension  of python file?
# Ans:-The extensions for Python files are – ".py"
#
#
# Q.05 Is python code complied or interpreted?
# Ans:- Python is an interpreted language, which means the source code of a Python program is converted into bytecode that is then executed by the Python virtual machine.
#
#
# Q.06 Name a few block of code used to define python language?
# Ans:-In Python we can define blocks of code using indentation.
#
# Q.07 State a character used to give single-line- comments in python.
# Ans:- '#' character used in python to give single-line comments.
#
#
# Q.08 Mention function which can help us to find the version of python that we are currently working on ?
# Ans:-The function 'sys. version' can help us to find the version of python that we are currently working on.
#
# Q.09 Python supports the creation  of anonymous function at runtime,using a construct called......
# Ans:- Lambda
#
#
# Q.10 What pip stand for python ?
# Ans:- pip stand for 'Preferred Installer Program'.
#
#
# Q.11 Mention a few built-in function in pyhthon?
# Ans:- tuple(),sum(),iter(),len(),str(),list(),int(),set(),type(),input() etc
#
#
# Q.12 What is maximum possible length of an identifier in pyhton?
# Ans:- An identifier can have a maximum length of 79 characters in Python.
#
#
# Q.13 What are the benefits of using pyhton?
# Ans:- Python is a popular programming language known for its simplicity, versatility, and readability.
#  High-Level Language,Open Source,Dynamically Typed,its Scalability these are some benefits of pyhton language.
#
#
#  Q.14 How is memory management in python?
#  Ans:-Memory management in Python involves a private heap containing all Python objects and data structures. The management of this private heap is ensured internally by the Python memory manager.
#
#
#  Q.15 How to install pyhton on windows and set path variable?
#  Ans:- Select the “Path” variable and click on the “Edit” button. In the “Edit Environment Variable” dialog, click on the “New” button and enter the path to your Python installation directory. Click “OK” to save the changes.
#
#
#  Q.16 Is indentation required in python?
#  Ans:- Indentation is a very important concept of Python because without properly indenting the Python code, we will end up seeing IndentationError and the code will not get compiled.
